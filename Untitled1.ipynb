# %%
import pandas as pd
import numpy as np
import datetime as dt
import seaborn as sns
from pathlib import Path


# %matplotlib inline

# %%
combined_data_path = Path('gas_clean.csv')

combined_data = pd.read_csv(combined_data_path)

# %%
influence_factors_data = combined_data[['U.S. Natural Gas Gross Withdrawals (MMcf)', 'U.S. Marketed Natural Gas Production (MMcf)', 'Alabama']]
influence_factors_data
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-29-42f32ce09e99> in <module>
# ----> 1 influence_factors_data = combined_data[['U.S. Natural Gas Gross Withdrawals (MMcf)', 'U.S. Marketed Natural Gas Production (MMcf)', 'Alabama']]
#       2 influence_factors_data
#
# ~/opt/anaconda3/envs/dev/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2906             if is_iterator(key):
#    2907                 key = list(key)
# -> 2908             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2909
#    2910         # take() does not accept boolean indexers
#
# ~/opt/anaconda3/envs/dev/lib/python3.7/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1252             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1253
# ...

# %%
combined_data.corr()
# Out:
#                    U.S.   Alabama    Alaska   Arizona   Arkansas   \
# U.S.            1.000000  0.938148  0.572949  0.895690   0.944004
# Alabama         0.938148  1.000000  0.755994  0.916527   0.926856
# Alaska          0.572949  0.755994  1.000000  0.652937   0.633255
# Arizona         0.895690  0.916527  0.652937  1.000000   0.896385
# Arkansas        0.944004  0.926856  0.633255  0.896385   1.000000
# California      0.837663  0.762020  0.522098  0.653454   0.746417
# Colorado        0.886922  0.893689  0.659892  0.811892   0.864850
# Connecticut     0.895146  0.818555  0.537263  0.751407   0.815301
# Delaware        0.857782  0.921388  0.688689  0.890975   0.881606
# DC              0.912167  0.913279  0.630387  0.847514   0.889826
# Florida         0.948139  0.945907  0.692251  0.855960   0.911777
# Georgia         0.925935  0.844779  0.432357  0.826037   0.895360
# Hawaii          0.665934  0.772707  0.766254  0.721523   0.686915
# ...
